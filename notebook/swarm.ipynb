# %% [markdown]
# ## 🐊 **Instalar stable**
#
# </details><img src='https://i.pinimg.com/originals/d4/63/f2/d463f24b0e1f3f1ce6680d601c97e6a0.gif' width='800px'/>
#
# <details>
# <summary><font color=gray>Últimos cambios</summary>
#
# > ☢️ Instalar: "Webui"
#
# > 🟢 Actualizar: "Configuración"
#
# > 🚩 Desinstalar: "Webui"
# </details>

# %%
"Instalar"
# %cd -q $HOME

# !curl -sLo ~/.conda/Interface.py https://github.com/SFcrypt/segsmaker-x/raw/main/config/Interface.py
# %run ~/.conda/Interface.py

# %% [markdown]
# ## 🦜 **Descargar Modelo**
#
# </details><img src='https://i.pinimg.com/originals/d4/63/f2/d463f24b0e1f3f1ce6680d601c97e6a0.gif' width='800px'/>
#
# <details>
# <summary><font color=gray>Últimos cambios</summary>
#
#
# > Descarga Modelo Illustrious
#
# > Descarga Modelos XL
#
# </details>

# %%
'Anime'
# %cd -q $CKPT

# %download https://huggingface.co/SFcrypt/illustrious-s/resolve/main/WAI-illustrious/WAI-illustrious.preview.png
# %download https://huggingface.co/SFcrypt/illustrious-s/resolve/main/WAI-illustrious/WAI-illustrious.safetensors

# %%
'Blender'
# %cd -q $CKPT

# %download https://huggingface.co/SFcrypt/illustrious-s/resolve/main/Nova-3D/Nova-3D.preview.png
# %download https://huggingface.co/SFcrypt/illustrious-s/resolve/main/Nova-3D/Nova-3D.safetensors

# %%
'Realistic'
# %cd -q $CKPT

# %download https://huggingface.co/SFcrypt/illustrious-s/resolve/main/Nova-reality/Nova-reality.preview.png
# %download https://huggingface.co/SFcrypt/illustrious-s/resolve/main/Nova-reality/Nova-reality.safetensors

# %%
'Controlnet'
# %cd -q /home/studio-lab-user/SwarmUI/Models/controlnet/

# %download https://huggingface.co/SFcrypt/controlnet-union/resolve/main/union.safetensors

# %% [markdown]
# ## 🎮 **Iniciar entorno**
#
# </details><img src='https://i.pinimg.com/originals/d4/63/f2/d463f24b0e1f3f1ce6680d601c97e6a0.gif' width='800px'/>
# <details>
#
# <summary><font color=gray>Comandos</summary>
#
# <span style="font-size:13px;">
#   <span style="color:#ab23ff">%</span>run segsmaker.<span style="color:#42a5f5">py</span>
#   <span style="color:#ab23ff">--</span>skip<span style="color:#ab23ff">-</span>widget
#   <span style="color:#ab23ff">--</span>skip<span style="color:#ab23ff">-</span>comfyui-check
# </span>
#
# </details>

# %%
"Iniciar"
# %cd -q $WebUI

# %run segsmaker.py
